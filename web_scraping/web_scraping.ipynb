# %%
import os, sys

# %%
ruta = os.path.dirname(os.getcwd())
sys.path.append(ruta)
from src.utils.folders_tb import Gestor_archivos
from src.utils.web_scraping_tb import Web_scraper

# %%
gestor = Gestor_archivos()
web_scraper = Web_scraper()

# %%
lista_url = {'ciudad': ['A Coruña', 'Barcelona', 'Bilbao', 'Girona', 'Lugo', 'Madrid', 'Salamanca', 'San Sebastián'], 
                'url': ['http://www.buscorestaurantes.com/restaurantes-con/facilidades-discapacitados/A-Coruna/a-coruna-capital',
                        'http://www.buscorestaurantes.com/restaurantes-con/facilidades-discapacitados/Barcelona/Barcelona',
                        'http://www.buscorestaurantes.com/restaurantes-con/facilidades-discapacitados/Bizkaia/Bilbao',
                        'http://www.buscorestaurantes.com/restaurantes-con/facilidades-discapacitados/Girona/Girona',
                        'http://www.buscorestaurantes.com/restaurantes-con/facilidades-discapacitados/Lugo/Lugo',
                        'http://www.buscorestaurantes.com/restaurantes-con/facilidades-discapacitados/madrid/madrid',
                        'http://www.buscorestaurantes.com/restaurantes-con/facilidades-discapacitados/Salamanca/Salamanca',
                        'http://www.buscorestaurantes.com/restaurantes-con/facilidades-discapacitados/Guipuzcoa/Donostia-San-Sebastian']}

# %%
web_scraper.scraping(lista_url)
# Out:
# La página 1 de A Coruña se ha registrado correctamente.
# La página 2 de A Coruña se ha registrado correctamente.
# La página 3 de A Coruña se ha registrado correctamente.
# La página 4 de A Coruña se ha registrado correctamente.
# La página 5 de A Coruña se ha registrado correctamente.
# La página 1 de Barcelona se ha registrado correctamente.
# La página 2 de Barcelona se ha registrado correctamente.
# La página 3 de Barcelona se ha registrado correctamente.
# La página 4 de Barcelona se ha registrado correctamente.
# La página 5 de Barcelona se ha registrado correctamente.
# La página 6 de Barcelona se ha registrado correctamente.
# La página 7 de Barcelona se ha registrado correctamente.
# La página 8 de Barcelona se ha registrado correctamente.
# La página 9 de Barcelona se ha registrado correctamente.
# La página 10 de Barcelona se ha registrado correctamente.
# La página 11 de Barcelona se ha registrado correctamente.
# ...

# %%
gestor.guardar_csv(web_scraper.dataframe, ruta=ruta, nombre='restaurantes_cuidades.csv')

# %%
data = web_scraper.dataframe
data
# Out:
#                           nombre         ciudad  \
# 0           Mirador de San Pedro       A Coruña
# 1     Trueiro (Meliá María Pita)       A Coruña
# 2              Restaurante Domus       A Coruña
# 3              Restaurante Aroma       A Coruña
# 4               Marisquería Suso       A Coruña
# ...                          ...            ...
# 1526                   Telepizza  San Sebastián
# 1527                   Telepizza  San Sebastián
# 1528          Restaurante Ni Neu  San Sebastián
# 1529            Alberto Jatetxea  San Sebastián
# 1530        Restaurante Astoria7  San Sebastián
#
#                                               direccion    latitud  longitud
# 0     Monte de San Pedro s/n (Parque Monte de San Pe...  43.377417 -8.433616
# 1     Avenida Pedro Barrié de la Maza, 1 (Orzán - Ma...  43.375155 -8.402867
# 2     Angel Rebollo, s/n\nA Coruña (Capital), A Coru...  43.377625 -8.406542
# 3     Comandante Fontanes, 6 (Playa del Orzan)\nA Co...  43.369942 -8.404874
# ...
